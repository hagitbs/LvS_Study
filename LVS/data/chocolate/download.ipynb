# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("atharvasoundankar/chocolate-sales")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/atharvasoundankar/chocolate-sales?dataset_version_number=4...
# 100%|██████████| 14.1k/14.1k [00:00<00:00, 8.58MB/s]
# Extracting files...
# Path to dataset files: /Users/hagitbenshoshan/.cache/kagglehub/datasets/atharvasoundankar/chocolate-sales/versions/4
